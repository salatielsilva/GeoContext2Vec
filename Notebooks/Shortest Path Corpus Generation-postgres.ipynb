# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import psycopg2 as postgres
import psycopg2.extras
import csv
import random
from sshtunnel import SSHTunnelForwarder
from tqdm import tqdm
import ast

# %% [markdown]
# # Util Functions

# %%
def executeQuery(conn, sql):
    """
    Executes a SQL query on a PostgreSQL database.

    Args:
        conn (psycopg2.extensions.connection): A connection object to the database.
        sql (str): The SQL query to execute.

    Returns:
        list: A list of records (tuples) retrieved from the database.
    """
    record = None
    try:
        cur = conn.cursor()
        cur.execute(sql)
        record = cur.fetchall()
        cur.close()
    except psycopg2.Error as e:
        print(e)
        cur.execute("ROLLBACK")
        cur.close()
    return record

# %%
def getPOIInformation(conn, business_id):
    """
    Retrieves information about a Point of Interest (POI) based on its ID.

    Args:
        conn (psycopg2.extensions.connection): A connection object to the database.
        business_id (str): The unique ID of the POI.

    Returns:
        list: A list of tuples containing checkin count and name for the specified POI.
    """
     sql = """
        SELECT checkin_count, name FROM pois_information WHERE id  = \'"""+str(business_id)+ """\'
    ;"""

    result = executeQuery(conn, sql)
    return result

# %%
# Generates the shortest path between the two most distant POIs in a zone.

def generate_path_corpus_all(bin_number, size):
    """
    Generates the shortest path between the two most distant POIs in a zone.

    Args:
        bin_number (int): The bin number.
        size (int): The size of the window around the POI.

    Returns:
        list: The corpus containing the shortest path sentences.
    """
    wnd = (bin_number + 1) * size

    with SSHTunnelForwarder(
        ('150.165.15.171', 23456),
        ssh_username="salatiel",
        ssh_password="Salatiel@Lacina123",
        remote_bind_address=('localhost', 5432)) as server:

            server.start()
    
            params = {'database': 'austin_test',
                      'user': 'salatiel',
                      'password': 'root',
                      'host': 'localhost',
                      'port': server.local_bind_port
                      }
    
            connection = psycopg2.connect(**params)
    
            file_name = './geographic/SHORTEST PATH/austin-shortest_path-' + str(bin_number) + '-FT-c_gpu.csv'
    
            print("Loading file:", file_name)
            all_pois_path = []
            with open(file_name, newline='') as f:
                csv_reader = csv.reader(f)
                for row in csv_reader:
                    all_pois_path.append(row)
    
            file_name_corpus = './geographic/SHORTEST PATH CORPUS/austin-shortest_path_corpus-' + str(bin_number) + '-FT-c_gpu.csv'
    
            csv_file = open(file_name_corpus, "w", newline='')
            writer = csv.writer(csv_file, delimiter=',')
            writer.writerow(["poi_id_center",
                             "center_poi",
                             "center_poi_level",
                             "context_poi",
                             "context_poi_level"])
    
            for poi_path in tqdm(all_pois_path):
                sub_path = list(range(0, wnd + 1))
                sub_path_types = []

                # Filling the initial list
                for sb_idx in sub_path:
                    if sb_idx < len(poi_path):
                        poi_id = poi_path[sb_idx]
                        poi_information = getPOIInformation(connection, poi_id)
                        if len(poi_information) > 0:
                            columns = list(dict(poi_information[0]).keys())
                            poi_information = pd.DataFrame(poi_information, columns=columns)
                            sub_path_types.append(poi_information)
                
                # Initiating the association process
                for i in range(len(poi_path)):
                    # Binary associations
                    # sub_path[0] is the target POI
                    target_types = sub_path_types[0]
                    for j in range(1, len(sub_path_types)):
                        neighbor_types = sub_path_types[j]
                        for id_t, tg in target_types.iterrows():
                            for id_n, ng in neighbor_types.iterrows():
                                if tg['name'] != ng['name']:
                                    line = [str(tg['id']),
                                            str(tg['name']),
                                            str(tg['level']),
                                            str(ng['name']),
                                            str(ng['level'])]
                                    writer.writerow(line)
                
                    new_poi = i + (wnd) + 1
                    sub_path.pop(0)
                    sub_path.append(new_poi)
                    sub_path_types.pop(0)
                
                    if new_poi < len(poi_path):

                        poi_id = poi_path[new_poi]
                        poi_information = getPOIInformation(connection, poi_id)

                        if (len(poi_information) > 0):

                            columns = list(dict(poi_information[0]).keys())
                            poi_information = pd.DataFrame(poi_information, columns=columns)
                            sub_path_types.append(poi_information)

            connection.close()
            csv_file.close()
            
    return None

# %%
def generate_path_corpus_zoning_all(all_pois_path, size):
    """
    Generates a corpus of sentences related to the shortest path between the two most distant POIs in a zone.

    Args:
        all_pois_path (list): A list of paths containing points of interest (POIs).
        size (int): The size of the window around the POI.

    Returns:
        list: The corpus containing sentences related to the shortest path.
    """
    wnd = size

    with SSHTunnelForwarder(
        ('150.165.15.171', 23456),
        ssh_username="salatiel",
        ssh_password="Salatiel@Lacina123",
        remote_bind_address=('localhost', 5432)) as server:

            server.start()
    
            params = {'database': 'austin_test',
                      'user': 'salatiel',
                      'password': 'root',
                      'host': 'localhost',
                      'port': server.local_bind_port
                      }
    
            connection = psycopg2.connect(**params)
    
            file_name_corpus = './austin-shortest_path_corpus-zoning-k' + str(wnd) + '-FT.csv'
    
            csv_file = open(file_name_corpus, "w", newline='')
            writer = csv.writer(csv_file, delimiter=',')
            writer.writerow(["poi_id_center",
                             "center_poi",
                             "center_poi_level",
                             "context_poi",
                             "context_poi_level"])
    
            for poi_path in tqdm(all_pois_path):
                sub_path = list(range(0, wnd + 1))
                sub_path_types = []
    
                # Fill initial list
                for sb_idx in sub_path:
                    if sb_idx < len(poi_path):
                        poi_id = poi_path[sb_idx]
                        poi_information = getPOIInformation(connection, poi_id)
                        if len(poi_information) > 0:
                            columns = list(dict(poi_information[0]).keys())
                            poi_information = pd.DataFrame(poi_information, columns=columns)
                            sub_path_types.append(poi_information)

                # Initiating the association process
                for i in range(len(poi_path)):
                    # Binary associations
                    # sub_path[0] is the target POI
                    target_types = sub_path_types[0]
                    for j in range(1, len(sub_path_types)):
                        neighbor_types = sub_path_types[j]
                        for id_t, tg in target_types.iterrows():
                            for id_n, ng in neighbor_types.iterrows():
                                if tg['name'] != ng['name']:
                                    line = [str(tg['id']),
                                            str(tg['name']),
                                            str(tg['level']),
                                            str(ng['name']),
                                            str(ng['level'])]
                                    writer.writerow(line)
                
                    new_poi = i + (wnd) + 1
                    sub_path.pop(0)
                    sub_path.append(new_poi)
                    sub_path_types.pop(0)
                
                    if new_poi < len(poi_path):
                        poi_id = poi_path[new_poi]
                        poi_information = getPOIInformation(connection, poi_id)
                        if len(poi_information) > 0:
                            columns = list(dict(poi_information[0]).keys())
                            poi_information = pd.DataFrame(poi_information, columns=columns)
                            sub_path_types.append(poi_information)

            connection.close()
            csv_file.close()
            
    return None

# %% [markdown]
# # Data Reading for Shortest Path Corpus Generation

# %%
#Reading Shortest Path generated with Zoning-Oriented Shortest Path Algorithm-postgres notebook
file_name = './austin-shortest_path-zoning-FT.csv'

print("loading file:", file_name)
all_pois_path = []
with open(file_name, newline='') as f:
    csv_reader = csv.reader(f)
    for row in csv_reader:
        all_pois_path.append(row)
        
all_pois_path[0]
# Out:
# loading file: ./geographic/SHORTEST PATH/austin-shortest_path-zoning-FT_gpu.csv
# ['q5Px_3plGESL2Bkdh2C42g',
#  'xRFcUSm2FyBNfF6hVoRB5A',
#  '6-HNU_8lBVytuVDAY-yIrw',
#  'tkyXRqZ4r0iE4xv7J2CBzA',
#  'ReoZ7TjusWClqEJqQEKT-w',
#  'SYfE-YgxaNp1Xg462NMjEw',
#  'b7ilYKdaFrxqmdRhq0IofA',
#  'PSYKGYT1y5jwvRYkjIC1Pw',
#  '5PhOJlCPHGjBEIQ7WLbRJw',
#  'aKBJN4P5mtmyycD04FAi0g',
#  'WM3DlKcaLLe8LSE7Oc33Tg',
#  '6WMNSsKE9iwENGGpRCBcMQ',
#  '9CLW_-8crptx7NJ2EDFO3Q',
#  '2Mf-GisSSU58WdEB7AW_hA',
#  '45ibpsh1mIwF6gZBycHOUg',
#  'JNjt0fgRmwVwyfdN0YvZfw',
#  'EBB3vTWxFG7ElJBc9IQCFQ',
#  'x7ogrkbPvQn2OdhFQC6DAQ',
#  'qlfFcoysbHe20OWXmDB1JQ',
#  '6xLrSOG-nfWZ4iwKspf4OA',
#  'yV1NfpKxiJMMrB4iyeaweA',
#  't-_Z9w96IPmTsP6XkYc3Rw',
#  'dxcHl17pVjen-SiHDeBiYw',
#  'c8yJlUCueOUXV7driq31pw',
#  'cn5jVlPb85Yt7ie0JnfW9w',
#  'nkxjj0JMBU3bCadjgpPoLQ',
#  'uVJ_vquU1PHXEHoZ9wYICw',
#  'MgPvLXqkgLomCClYwHy2Dw',
#  'r9P2d6A5UBoiMe4fYtlgQg',
#  'IYzIsCpu9zK3fs1nz3UgEA',
#  '6ULOwdJbJPlmNuHsmRCURA',
#  '2xjEoFTFjo-xQlcLdW-Jcg',
#  'HylKM5pURvTgK51qSHlrKA',
#  'htpL7K2x19BdhJsAE9lWYA',
#  'fLQCXGls7SeS5UgGKALoDA',
#  'D0gVLzoHCDwXw6BNRYOScw',
#  '-0pSig1ffET5-fr3p4LkWg',
#  'm4vLxvcI08uDeROuKFDfAA',
#  'OPBbKR0cT_0YpsQRJI4RNg',
#  'bPmtkrBDkhJLX4JUMyjVyg',
#  'jsck95mC2XrNEQzs0WrIBg',
#  'cIepiuF8L9f1EKYvLOceEw',
#  'XmcJuedxXv8Lh1MufHgOnA',
#  'z0t5xVf2bA0-o6BKoazUXA',
#  'CEfccUwLjIJG58YE_R1J9w',
#  'VvPVMUiqxeMd7MsdUqb1Sw',
#  'SMRzg0De5QV6Lk1myq3zrQ',
#  'Aec1jwaUz-wrbvC3iooBCA',
#  'E-klmrISl2zK_Yahj8J_4Q',
#  'QJH0rwKDyufME6Ic3kj0-g',
#  'x0506n4GE4_jgUrDegtaGQ',
#  'r1SFwWjURdlQgb-WhNZFdQ',
#  '7m-Fzi_PSxXWZ3K_-g9AUg',
#  '--z9usx6Fin8P_f0vc7DGQ',
#  'cm4zixZWV2899wdfZUEuNQ',
#  'iC1NqqXy_qpSCEC-pQAPoQ',
#  'Ht6p_oiK7lZzngmA2pEH8w',
#  'YTK0mTEOEWwnLGfsJwuQhA',
#  'mJuGFcJ0TXYSPHQRuSYWuw',
#  'zFqBBiYUY_hdTYhyvlr4sQ',
#  'aHkdHfN2dTHkR6INyVM5sQ',
#  'EM2xvBhMvOhCDmS3eZi0Vg',
#  'VL-CmfZXJbhJiVHsqxP_1Q',
#  'I_QntbIF9Pkqx2nf2q-VvQ',
#  'BZGfVuuLu11_lzGv0gbLpg',
#  'X4_bB1Mmd2OF3kvrOkRA6A',
#  'K73m42-HwW4To6f5UInJVA',
#  'ZSQrkE_pdoT3tDewU7jsdg',
#  '1cZkr2kGfvtMkIfN1AYeIQ',
#  'jxari_BeJi7j2reRSrDnTw',
#  'lpH82VmjtGGoZoOsUVUfDw',
#  'oZlZAj03sZhzjEoCzNW48w',
#  '3U8uqCpUHyYaTl25UvFItA',
#  'ZsUmFw2bCVjhHvPIMvEFog',
#  'C9H3Lggry7JoZmfNTfNPqA',
#  'OSt-BzuBDh14IF0V4qffIg',
#  '_HYFLsAYXIyJtLWKTe2PUQ',
#  'LHxDcsscgG-POCxFnxMrsg',
#  'sBi3bm-zO6uGxrX9nQFBIA',
#  'gkR3uzkZCtgEB-m4O9-Isg',
#  'WhSxfYNJiuVSrDnQMmsnUg',
#  '_LSIxelroAHfIk0CRYtq8g',
#  'D44wh85iHuWFkNCmxOdlmA',
#  'u_hxONpTSyWaH5Q0STCJPA',
#  'HTJ3miAgR_wtHbsaVOYgDA',
#  'xAb9pWWCkhoWxCRGQD0WSw',
#  'A2kplIOTO_aD80o2jMyQ8g',
#  'HOuxYlBGRU3pQ2pZ6Y4-fA',
#  'wwpF0SXeKHo901C8-IalbQ',
#  'YnubfQ2OmNEA4SYUewzU0Q',
#  'zKcGOa_r9U9v23Aj43Zg-g',
#  'IQ9SenhkucKpdNpfs0GurA',
#  'CR0SM5mgpNOYm7HZuvIV3g',
#  '1U7sO0sUAynouMzyS1w_fQ',
#  'Ctn-ftA3qG6PIwSbmFz4dA',
#  'EiyCia2uZiVl3T3TEb6kiA',
#  'V5waUxl6O7nKLCSnoyDzlg',
#  'E8ko4JobpyC5AmTDJ9BQRQ',
#  '_PQ5cChvOleL3DotAmNkyg',
#  'Uy90pBEk1OfmHIbwvaJnfw',
#  'IAwX9ypeyf4y88mS6YZvIw',
#  'tkRYbm3ObBL7sV7XfCwRfQ',
#  '28gLYlL569Bdb-zx7XRKzQ',
#  'qVMuV4pqPkRaTCZ65eIj1A',
#  'eh9jMKcjq5LymwhvWEBiCg',
#  'eFENVZwRLblsIDiFQU_XNw',
#  'aQOfzotmSyQ8Ox1e3aEThA',
#  'Hvln9fM_gYmKOBMhx0j_DQ',
#  'z5SEfnihnLnWnI1F7QHb7A',
#  'npiEnwFNcOpSzK3-qVfRZA',
#  'YD-LzwGdNAE1CQLXDl_T4A',
#  'vnf56mfsMgIMZRx0Mu0kvQ',
#  'UPjtrNe-txl4zS52tBaZaw',
#  'htjk4jARqDhnkVRYVSWU1w',
#  'xwM07ux1or_vrYUi09SObg',
#  'L7SxI1Kq63LMQTcKuxdjoQ',
#  '2BxfPhAcR_1WlZhU2AHHJw',
#  'yCMGT0_eOHwCWl6UwbmOag',
#  'fqtecjWBU83jnx2brDm5mw',
#  'Hzl6tceihYgRpCWL4bKgvQ',
#  'Yts3xkuJf2l0TH3utk9dlw',
#  '7a3dsFx4x80eJh9n5gmwSg',
#  'RkXXV6ACzRm76pC0qDiTPg',
#  'bKXudCzxsYjkcGFsj3nZDA',
#  'P7-P5WpjDr96r_2RzYVORQ',
#  'XcnrzZzFDpwMekeXaujRgw',
#  'Sz7QVo7UXqp0WncPr34srg',
#  '_lq_9VoEmX3JwZH4Yxbkdg',
#  'GBLZ36WYsHmmoWi7u9W1cw',
#  '-oMIzR8lRb-HlqQ1gjqDfA',
#  'rhsj8ISdsDM-4QHeTfvyPA',
#  'Qz-R16P6zvgJrRerqdtIaQ',
#  'jD-blERn1CzMrq_FLQfd4w',
#  '6F9RgnrGBb9e2cWmAKKlng',
#  'pEPPBEF2QEIvNV2SgLVDkQ',
#  '2Ma4ofw8Lmq7NQkD00uNLw',
#  'FuCx_MkgCkwpsAs8wXt-Qw',
#  'bMGhxXwrktLshwFVVUqfpw',
#  '3C-AKE1SctZZruBtxGX0vQ',
#  'vMdNXVXvZSWghFbUJduzrw',
#  'j0lh5qJnDtiacFrLswpwDg',
#  's5-0axDB6gGd-J0hIwz1Kg',
#  'o9QvjwS-zhqzQfaHgJjHug',
#  'rO2utt6SJTP5sjaUsiMQbw',
#  'qdNNoRt5ukQa0fANrd5AAg',
#  'cjpVyhGF2nOsrJscuN0x8w',
#  'bL2Tc9Q-BKOjy1qttVb2nA',
#  'zg8SNwoxeX6vVc1d186xuQ',
#  '6DZ9u5864fiQhGLc1dwFAQ',
#  'WJkLQ9r_lDmntVTCQHJPig',
#  'NRPemqVb4qpWFF0Avq_6OQ',
#  'pll5B4WeRc67mm72hr8j2Q',
#  'uKPst2lrM8EmrPvVH2GLgw',
#  'qIKBA-X_Whufbodcok0czA',
#  'qtD3LT974tcvOBldzQqHRw',
#  'WFItVbcpiGVQrK_DxeMZDQ',
#  'DbUHLH7qnbH-eqx4x4SltA',
#  'QXvAW1PO2cQpbD8RyXhV2Q',
#  'o4ozpA9aZzpnLZNiFXpMSw',
#  'oqip_OcSIf2-3DV6KqyLlQ',
#  '_FNm3TiPE5w3eJHOS3TMhA',
#  '9m79-dehItPYbs2KJpH38w',
#  'ObARwNdwAtFSFwhr1tHCdA',
#  'IZmg0KbcMdfJjmStmH87Qw',
#  'uE11NwsGcJMghl7QIlED5Q',
#  '_hGGnm3wuop0WrEpKMYOeA',
#  '6HwWz3yfEz1aAb_GO6OY2Q',
#  'iexKSlIJWuMwE4u93g_-_w',
#  'mgt3cXHf3vKvU6TZVyO2Qw',
#  '99bY0MwtzCTBSOnNjP4GKw',
#  'DmMa5LefZkfVxT28U4PaBg',
#  'v-GmOYEbepRagKluC0Sgdg',
#  'vAy5Nzbk1Fl_DUVdxKndww',
#  'SQXLFu-htDo4GC0BZUxO8g',
#  'ldqYM7k3a-pbzqkzcsevuQ',
#  '3kHdU9xtB3MTx3du-ZLi6g',
#  '7JujKMcy0UzqQ5gS2gLXlQ',
#  'ajQNdP0CzJpLKC0qd2xoGg',
#  'ycD_0krLOhaF4ZRukzEVLA',
#  'lEUhm4PCsdKiCxHzREOEjA',
#  'k6zPTAgo7XLB4zKhCCXVzQ',
#  'YHOHQMkvev5ySf94XYTplw',
#  'ChqHUmWQh1AapbxzGJ2mGg',
#  't4idMNEUIzLgs2hDNwoNNg',
#  'FXiDVz_dRWllR11SF2nz4Q',
#  'inI8KDSPGQlWjjI1Ll4EzA',
#  'Dvl6o2K1EWzkeR9avJYtog',
#  'K9VYJiNAq-nIMfxGFxLhtA',
#  '6VbaBeHWV61-NKpF1tb__Q',
#  'GSUxP9n8rwZ2cTju9iT-2Q',
#  '0Q7eC_Bhut-8Rd-qiH7XEQ',
#  'wJ2E9YqgInCNNy5wXCwiAg',
#  '2eXji-JyL4J_oBoQoE-O0g',
#  'RlD_kVvScNw_I9LPyjUMZw',
#  '-2HO6CEgR80_QQTpgq0Bwg',
#  'oUUTI_B0oB4DYDKSDlIASg',
#  'eHktA_TStENB5lA83Es0Nw',
#  'PB_ynEp2-4rHov0gRqw8Eg',
#  'oJjmM81g214TGKdmHNcjHQ',
#  'u1TebZx4GCBTAgiou_ds0w',
#  'NiHwykOSP1qt7jwf3auPcQ',
#  'gwwKe0Kfm79mqY4Fuz2ZGw',
#  'w9LLj7IkCWkt45ZR3k99Gg',
#  '180iG4-reNJmLO0pZshJmw',
#  '3rMQRtMfPJsleM2EiyAuZA',
#  'v0i7m-V1oiBallbv308S4g',
#  'EodbQesFTzdtPED11DrrvQ',
#  'lL9NaDLdCBiAQ4HBcumbgg',
#  '9_pEIXrrkD_YFpetd3phxg',
#  'r2LhcAYeM5PXtbZDg8T0_A',
#  'TgiU63iufrIij1nSyIPj_g',
#  'KAMYRUsNilk7sHzzbcGZnQ',
#  'HR5WpkM9rFHJaSTXHkxsaQ',
#  'jsD7fVCBKdBAISiKGuv-xg',
#  'Ca1opwJEEe4NHizoAQQrGw',
#  'KzXeYr0LJWUr-Kt0l1ObnQ',
#  'alDP_cWqJk_WtW1YWoAHqw',
#  'Iy2wEDVQZ9GTeN3m5F2blA',
#  'qT5Wt2yEafvoXdAresiImQ',
#  'FdPk6tcn7r2uHBRWI6eUXA',
#  'jTNl0ip2Et7VDLvkGxittA',
#  'qZmlxeKpXtvf78mcPpTOnQ',
#  'WIRhjSSGFnvXmQMzVou9xg',
#  'HOcc3qoSotKFrX2tfIP5kg',
#  'y_4w8mtLYgi3Hy4EqH1jew',
#  'DIrwdtbw8nIDUcfU_9c4AA',
#  'nvrOGHRDucxeNkplIikM2A',
#  'ORR_74qq9gxLGOkDfP_FmQ',
#  'jBIMPzqCFpv4iwMYkYo9Kw',
#  '76Snck54joMhu_332ZTOuA',
#  'pOK80-GN3odM7bofC7RjcA',
#  '3-crabLCDiobw8CvKxKJJw',
#  'Zc1W6gL9PSa8QAP_bI25VQ',
#  '_fqv8een2N_B5BSca_Yoag',
#  '8QgoJ7owwE37bJrzsYRUOQ',
#  '3DFvutUSvHebYJ0Lb1oW6g',
#  'xUc8I6wsM0YNllO61OR9CQ']

# %% [markdown]
# # Word2Vec Sentence Generation Process

# %%
#Produces sentences by randomly selecting a type of POI from the shortest path.
for rnd in range(0, 12):
    with SSHTunnelForwarder(
        ('localhost', 22),
        # ssh_private_key="</path/to/private/ssh/key>",
        ### in my case, I used a password instead of a private key
        ssh_username="root",
        ssh_password="root",
        remote_bind_address=('localhost', 5432)
    ) as server:
        server.start()
        # print("server connected")

        params = {
            'database': 'austin_test',
            'user': 'postgres',
            'password': 'root',
            'host': 'localhost',
            'port': server.local_bind_port
        }

        connection = psycopg2.connect(**params)

        all_sentences = []

        for poi_path in tqdm(all_pois_path):
            # for poi_path in all_pois_path:
            poi_path_sentence = []
            for poi_id in poi_path:
                # Obtaining category and check-in information for the central POI
                # [business_id, checkin, category]
                poi_information = getPOIInformation(connection, poi_id)

                if len(poi_information) > 0:
                    columns = list(dict(poi_information[0]).keys())
                    poi_information = pd.DataFrame(poi_information, columns=columns)

                    type_by_level = []

                    for level in range(5):
                        level_poi_information = poi_information[poi_information['level'] == level]
                        poi_types = list(level_poi_information['name'])
                        if len(poi_types) > 0:
                            poi_type = poi_types[random.randint(0, len(poi_types) - 1)]
                            type_by_level.append(poi_type)

                    # Select randomly from all types
                    selected_type = type_by_level[random.randint(0, len(type_by_level) - 1)]
                    poi_path_sentence.append(selected_type)


            all_sentences.append(poi_path_sentence)
            
    file_name = './austin-shortest_path_corpus-' + str(bin_number) + '-rnd'+str(rnd)+'-FT-c.csv'

    csv_file_02 = open(file_name, "w", newline='')
    writer_path = csv.writer(csv_file_02, delimiter=',')
    for st in all_sentences:
        writer_path.writerow(st)
# Out:
# 100%|██████████| 22399/22399 [20:30<00:00, 18.20it/s]
# 100%|██████████| 22399/22399 [20:25<00:00, 18.28it/s]
# 100%|██████████| 22399/22399 [20:33<00:00, 18.16it/s]
# 100%|██████████| 22399/22399 [20:29<00:00, 18.22it/s]
#  65%|██████▍   | 14473/22399 [13:19<08:16, 15.97it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#  72%|███████▏  | 16060/22399 [14:46<08:43, 12.10it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Parallel Execution

# %%
pois_file_name = './austin-ml-updated.csv'
poi_df = pd.read_csv(pois_file_name)
print(poi_df.shape)
poi_df = poi_df.dropna()
print(poi_df.shape)
poi_df.head()
# Out:
# (22399, 7)
# (22399, 7)
#               business_id    city state   latitude  longitude  \
# 0  N3_Gs3DnX4k9SgpwJxdEfw  Austin    TX  30.346169 -97.711458
# 1  tXvdYGvlEceDljN8gt2_3Q  Austin    TX  30.172706 -97.799920
# 2  nTIhpR7MhsALPwg_Hh14EA  Austin    TX  30.326377 -97.704543
# 3  8XyEpVdAO0o6iVkVxkWosQ  Austin    TX  30.246465 -97.778738
# 4  NVfOn7TdnHbaGH97CVB_Qg  Austin    TX  30.244902 -97.857409
#
#                                           categories  checkin_count
# 0  Shopping, Jewelry Repair, Appraisal Services, ...             14
# 1                             Barbers, Beauty & Spas              1
# 2  Hotels, Hotels & Travel, Event Planning & Serv...            475
# 3    Home Services, Real Estate, Property Management              0
# 4                    Chiropractors, Health & Medical             33

# %%
import multiprocessing as mp
print("Number of processors: ", mp.cpu_count())

# Step 1: Init multiprocessing.Pool()
pool = mp.Pool(int(mp.cpu_count()))


# Step 2: `pool.apply` the `howmany_within_range()`
size = [10, 20, 30, 40, 50, 60, 70, 80, 90]
pool.starmap(generate_path_corpus_zoning_all, [(all_pois_path, sz) for sz in size])

# Step 3: Don't forget to close
pool.close()

#Para point
#calculateBinOSMPoints_Disco(df, n)
# Out:
# Number of processors:  20
# 100%|██████████| 105/105 [05:17<00:00,  3.03s/it]]
# 100%|██████████| 105/105 [08:48<00:00,  5.03s/it]t]
# 100%|██████████| 105/105 [11:58<00:00,  6.85s/it] ]
# 100%|██████████| 105/105 [15:09<00:00,  8.67s/it]
# 100%|██████████| 105/105 [18:14<00:00, 10.42s/it]
# 100%|██████████| 105/105 [21:30<00:00, 12.29s/it]
# 100%|██████████| 105/105 [23:58<00:00, 13.70s/it]
# 100%|██████████| 105/105 [26:38<00:00, 15.23s/it]
# 100%|██████████| 105/105 [29:06<00:00, 16.63s/it]
